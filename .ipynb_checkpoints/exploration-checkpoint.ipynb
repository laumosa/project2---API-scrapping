# %% [markdown]
# # PROJECT 2

# %% [markdown]
# ## 1. Import libraries

# %%
import pandas as pd
from pandas import json_normalize

import requests 
import json
import os
from dotenv import load_dotenv 
import time

import sys
sys.path.append("../")

load_dotenv()

# %% [markdown]
# ## 2. Access API

# %%
KEY = os.getenv("API_KEY")

# %%
params = {
  'access_key': KEY
}

api_result = requests.get('http://api.aviationstack.com/v1/flights', params)

api_response = api_result.json()
api_response
# Out:
# {'pagination': {'limit': 100, 'offset': 0, 'count': 100, 'total': 423143},
#  'data': [{'flight_date': '2023-04-29',
#    'flight_status': 'scheduled',
#    'departure': {'airport': 'Abha',
#     'timezone': 'Asia/Riyadh',
#     'iata': 'AHB',
#     'icao': 'OEAB',
#     'terminal': None,
#     'gate': None,
#     'delay': None,
#     'scheduled': '2023-04-29T01:05:00+00:00',
#     'estimated': '2023-04-29T01:05:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'King Abdulaziz International',
#     'timezone': 'Asia/Riyadh',
#     'iata': 'JED',
#     'icao': 'OEJN',
#     'terminal': '1',
#     'gate': None,
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2023-04-29T02:20:00+00:00',
#     'estimated': '2023-04-29T02:20:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'flynas', 'iata': 'XY', 'icao': 'KNE'},
#    'flight': {'number': '436',
#     'iata': 'XY436',
#     'icao': 'KNE436',
#     'codeshared': None},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2023-04-29',
#    'flight_status': 'scheduled',
#    'departure': {'airport': 'Abha',
#     'timezone': 'Asia/Riyadh',
#     'iata': 'AHB',
#     'icao': 'OEAB',
#     'terminal': None,
#     'gate': None,
#     'delay': None,
#     'scheduled': '2023-04-29T00:35:00+00:00',
#     'estimated': '2023-04-29T00:35:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'King Khaled International',
#     'timezone': 'Asia/Riyadh',
#     'iata': 'RUH',
#     'icao': 'OERK',
#     'terminal': '5',
#     'gate': None,
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2023-04-29T02:20:00+00:00',
#     'estimated': '2023-04-29T02:20:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Saudia', 'iata': 'SV', 'icao': 'SVA'},
#    'flight': {'number': '1680',
#     'iata': 'SV1680',
#     'icao': 'SVA1680',
#     'codeshared': None},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2023-04-29',
#    'flight_status': 'scheduled',
#    'departure': {'airport': 'Tribhuvan International',
#     'timezone': 'Asia/Kathmandu',
#     'iata': 'KTM',
#     'icao': 'VNKT',
#     'terminal': None,
#     'gate': None,
#     'delay': None,
#     'scheduled': '2023-04-29T03:05:00+00:00',
#     'estimated': '2023-04-29T03:05:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Dhangarhi',
#     'timezone': 'Asia/Kathmandu',
#     'iata': 'DHI',
#     'icao': 'VNDH',
#     'terminal': None,
#     'gate': None,
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2023-04-29T03:55:00+00:00',
#     'estimated': '2023-04-29T03:55:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Sharp Airlines', 'iata': 'SH', 'icao': 'SHA'},
#    'flight': {'number': '225',
#     'iata': 'SH225',
#     'icao': 'SHA225',
#     'codeshared': None},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2023-04-29',
#    'flight_status': 'active',
#    'departure': {'airport': 'Singapore Changi',
#     'timezone': 'Asia/Singapore',
#     'iata': 'SIN',
#     'icao': 'WSSS',
#     'terminal': '3',
#     'gate': 'C1',
#     'delay': None,
#     'scheduled': '2023-04-29T00:25:00+00:00',
#     'estimated': '2023-04-29T00:25:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Melbourne - Tullamarine Airport',
#     'timezone': 'Australia/Melbourne',
#     'iata': 'MEL',
#     'icao': 'YMML',
#     'terminal': '2',
#     'gate': None,
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2023-04-29T09:50:00+00:00',
#     'estimated': '2023-04-29T09:50:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Virgin Australia', 'iata': 'VA', 'icao': 'VOZ'},
#    'flight': {'number': '5537',
#     'iata': 'VA5537',
#     'icao': 'VOZ5537',
#     'codeshared': {'airline_name': 'singapore airlines',
#      'airline_iata': 'sq',
#      'airline_icao': 'sia',
#      'flight_number': '237',
#      'flight_iata': 'sq237',
#      'flight_icao': 'sia237'}},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2023-04-29',
#    'flight_status': 'active',
#    'departure': {'airport': 'Singapore Changi',
#     'timezone': 'Asia/Singapore',
#     'iata': 'SIN',
#     'icao': 'WSSS',
#     'terminal': '3',
#     'gate': 'C1',
#     'delay': None,
#     'scheduled': '2023-04-29T00:25:00+00:00',
#     'estimated': '2023-04-29T00:25:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Melbourne - Tullamarine Airport',
#     'timezone': 'Australia/Melbourne',
#     'iata': 'MEL',
#     'icao': 'YMML',
#     'terminal': '2',
#     'gate': None,
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2023-04-29T09:50:00+00:00',
#     'estimated': '2023-04-29T09:50:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Vistara', 'iata': 'UK', 'icao': 'VTI'},
#    'flight': {'number': '8237',
#     'iata': 'UK8237',
#     'icao': 'VTI8237',
#     'codeshared': {'airline_name': 'singapore airlines',
#      'airline_iata': 'sq',
#      'airline_icao': 'sia',
#      'flight_number': '237',
#      'flight_iata': 'sq237',
#      'flight_icao': 'sia237'}},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2023-04-29',
#    'flight_status': 'active',
#    'departure': {'airport': 'Singapore Changi',
#     'timezone': 'Asia/Singapore',
#     'iata': 'SIN',
#     'icao': 'WSSS',
#     'terminal': '3',
#     'gate': 'C1',
#     'delay': None,
#     'scheduled': '2023-04-29T00:25:00+00:00',
#     'estimated': '2023-04-29T00:25:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Melbourne - Tullamarine Airport',
#     'timezone': 'Australia/Melbourne',
#     'iata': 'MEL',
#     'icao': 'YMML',
#     'terminal': '2',
#     'gate': None,
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2023-04-29T09:50:00+00:00',
#     'estimated': '2023-04-29T09:50:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Turkish Airlines', 'iata': 'TK', 'icao': 'THY'},
#    'flight': {'number': '9324',
#     'iata': 'TK9324',
#     'icao': 'THY9324',
#     'codeshared': {'airline_name': 'singapore airlines',
#      'airline_iata': 'sq',
#      'airline_icao': 'sia',
#      'flight_number': '237',
#      'flight_iata': 'sq237',
#      'flight_icao': 'sia237'}},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2023-04-29',
#    'flight_status': 'active',
#    'departure': {'airport': 'Singapore Changi',
#     'timezone': 'Asia/Singapore',
#     'iata': 'SIN',
#     'icao': 'WSSS',
#     'terminal': '3',
#     'gate': 'C1',
#     'delay': None,
#     'scheduled': '2023-04-29T00:25:00+00:00',
#     'estimated': '2023-04-29T00:25:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Melbourne - Tullamarine Airport',
#     'timezone': 'Australia/Melbourne',
#     'iata': 'MEL',
#     'icao': 'YMML',
#     'terminal': '2',
#     'gate': None,
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2023-04-29T09:50:00+00:00',
#     'estimated': '2023-04-29T09:50:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'SAS', 'iata': 'SK', 'icao': 'SAS'},
#    'flight': {'number': '8063',
#     'iata': 'SK8063',
#     'icao': 'SAS8063',
#     'codeshared': {'airline_name': 'singapore airlines',
#      'airline_iata': 'sq',
#      'airline_icao': 'sia',
#      'flight_number': '237',
#      'flight_iata': 'sq237',
#      'flight_icao': 'sia237'}},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2023-04-29',
#    'flight_status': 'active',
#    'departure': {'airport': 'Singapore Changi',
#     'timezone': 'Asia/Singapore',
#     'iata': 'SIN',
#     'icao': 'WSSS',
#     'terminal': '3',
#     'gate': 'C1',
#     'delay': None,
#     'scheduled': '2023-04-29T00:25:00+00:00',
#     'estimated': '2023-04-29T00:25:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Melbourne - Tullamarine Airport',
#     'timezone': 'Australia/Melbourne',
#     'iata': 'MEL',
#     'icao': 'YMML',
#     'terminal': '2',
#     'gate': None,
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2023-04-29T09:50:00+00:00',
#     'estimated': '2023-04-29T09:50:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'SWISS', 'iata': 'LX', 'icao': 'SWR'},
#    'flight': {'number': '9074',
#     'iata': 'LX9074',
#     'icao': 'SWR9074',
#     'codeshared': {'airline_name': 'singapore airlines',
#      'airline_iata': 'sq',
#      'airline_icao': 'sia',
#      'flight_number': '237',
#      'flight_iata': 'sq237',
#      'flight_icao': 'sia237'}},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2023-04-29',
#    'flight_status': 'active',
#    'departure': {'airport': 'Singapore Changi',
#     'timezone': 'Asia/Singapore',
#     'iata': 'SIN',
#     'icao': 'WSSS',
#     'terminal': '3',
#     'gate': 'C1',
#     'delay': None,
#     'scheduled': '2023-04-29T00:25:00+00:00',
#     'estimated': '2023-04-29T00:25:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Melbourne - Tullamarine Airport',
#     'timezone': 'Australia/Melbourne',
#     'iata': 'MEL',
#     'icao': 'YMML',
#     'terminal': '2',
#     'gate': None,
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2023-04-29T09:50:00+00:00',
#     'estimated': '2023-04-29T09:50:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'},
#    'flight': {'number': '7204',
#     'iata': 'LH7204',
#     'icao': 'DLH7204',
#     'codeshared': {'airline_name': 'singapore airlines',
#      'airline_iata': 'sq',
#      'airline_icao': 'sia',
#      'flight_number': '237',
#      'flight_iata': 'sq237',
#      'flight_icao': 'sia237'}},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2023-04-29',
#    'flight_status': 'active',
#    'departure': {'airport': 'Singapore Changi',
#     'timezone': 'Asia/Singapore',
#     'iata': 'SIN',
#     'icao': 'WSSS',
#     'terminal': '3',
#     'gate': 'C1',
#     'delay': None,
#     'scheduled': '2023-04-29T00:25:00+00:00',
#     'estimated': '2023-04-29T00:25:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Melbourne - Tullamarine Airport',
#     'timezone': 'Australia/Melbourne',
#     'iata': 'MEL',
#     'icao': 'YMML',
#     'terminal': '2',
#     'gate': None,
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2023-04-29T09:50:00+00:00',
#     'estimated': '2023-04-29T09:50:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Ethiopian Airlines', 'iata': 'ET', 'icao': 'ETH'},
#    'flight': {'number': '1303',
#     'iata': 'ET1303',
#     'icao': 'ETH1303',
#     'codeshared': {'airline_name': 'singapore airlines',
#      'airline_iata': 'sq',
#      'airline_icao': 'sia',
#      'flight_number': '237',
#      'flight_iata': 'sq237',
#      'flight_icao': 'sia237'}},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2023-04-29',
#    'flight_status': 'active',
#    'departure': {'airport': 'Singapore Changi',
#     'timezone': 'Asia/Singapore',
#     'iata': 'SIN',
#     'icao': 'WSSS',
#     'terminal': '3',
#     'gate': 'B8',
#     'delay': None,
#     'scheduled': '2023-04-29T00:10:00+00:00',
#     'estimated': '2023-04-29T00:10:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Seoul (Incheon)',
#     'timezone': 'Asia/Seoul',
#     'iata': 'ICN',
#     'icao': 'RKSI',
#     'terminal': '1',
#     'gate': '23',
#     'baggage': '4',
#     'delay': None,
#     'scheduled': '2023-04-29T07:45:00+00:00',
#     'estimated': '2023-04-29T07:45:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Virgin Australia', 'iata': 'VA', 'icao': 'VOZ'},
#    'flight': {'number': '5678',
#     'iata': 'VA5678',
#     'icao': 'VOZ5678',
#     'codeshared': {'airline_name': 'singapore airlines',
#      'airline_iata': 'sq',
#      'airline_icao': 'sia',
#      'flight_number': '608',
#      'flight_iata': 'sq608',
#      'flight_icao': 'sia608'}},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2023-04-29',
#    'flight_status': 'active',
#    'departure': {'airport': 'Singapore Changi',
#     'timezone': 'Asia/Singapore',
#     'iata': 'SIN',
#     'icao': 'WSSS',
#     'terminal': '3',
#     'gate': 'B8',
#     'delay': None,
#     'scheduled': '2023-04-29T00:10:00+00:00',
#     'estimated': '2023-04-29T00:10:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Seoul (Incheon)',
#     'timezone': 'Asia/Seoul',
#     'iata': 'ICN',
#     'icao': 'RKSI',
#     'terminal': '1',
#     'gate': '23',
#     'baggage': '4',
#     'delay': None,
#     'scheduled': '2023-04-29T07:45:00+00:00',
#     'estimated': '2023-04-29T07:45:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Asiana Airlines', 'iata': 'OZ', 'icao': 'AAR'},
#    'flight': {'number': '6782',
#     'iata': 'OZ6782',
#     'icao': 'AAR6782',
#     'codeshared': {'airline_name': 'singapore airlines',
#      'airline_iata': 'sq',
#      'airline_icao': 'sia',
#      'flight_number': '608',
#      'flight_iata': 'sq608',
#      'flight_icao': 'sia608'}},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2023-04-29',
#    'flight_status': 'active',
#    'departure': {'airport': 'Singapore Changi',
#     'timezone': 'Asia/Singapore',
#     'iata': 'SIN',
#     'icao': 'WSSS',
#     'terminal': '3',
#     'gate': 'B8',
#     'delay': None,
#     'scheduled': '2023-04-29T00:10:00+00:00',
#     'estimated': '2023-04-29T00:10:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Seoul (Incheon)',
#     'timezone': 'Asia/Seoul',
#     'iata': 'ICN',
#     'icao': 'RKSI',
#     'terminal': '1',
#     'gate': '23',
#     'baggage': '4',
#     'delay': None,
#     'scheduled': '2023-04-29T07:45:00+00:00',
#     'estimated': '2023-04-29T07:45:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Air Canada', 'iata': 'AC', 'icao': 'ACA'},
#    'flight': {'number': '6307',
#     'iata': 'AC6307',
#     'icao': 'ACA6307',
#     'codeshared': {'airline_name': 'singapore airlines',
#      'airline_iata': 'sq',
#      'airline_icao': 'sia',
#      'flight_number': '608',
#      'flight_iata': 'sq608',
#      'flight_icao': 'sia608'}},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2023-04-29',
#    'flight_status': 'active',
#    'departure': {'airport': 'Singapore Changi',
#     'timezone': 'Asia/Singapore',
#     'iata': 'SIN',
#     'icao': 'WSSS',
#     'terminal': '3',
#     'gate': 'C22',
#     'delay': 10,
#     'scheduled': '2023-04-29T00:05:00+00:00',
#     'estimated': '2023-04-29T00:05:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Kastrup',
#     'timezone': 'Europe/Copenhagen',
#     'iata': 'CPH',
#     'icao': 'EKCH',
#     'terminal': '3',
#     'gate': None,
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2023-04-29T07:10:00+00:00',
#     'estimated': '2023-04-29T07:10:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Virgin Australia', 'iata': 'VA', 'icao': 'VOZ'},
#    'flight': {'number': '5582',
#     'iata': 'VA5582',
#     'icao': 'VOZ5582',
#     'codeshared': {'airline_name': 'singapore airlines',
#      'airline_iata': 'sq',
#      'airline_icao': 'sia',
#      'flight_number': '352',
#      'flight_iata': 'sq352',
#      'flight_icao': 'sia352'}},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2023-04-29',
#    'flight_status': 'active',
#    'departure': {'airport': 'Singapore Changi',
#     'timezone': 'Asia/Singapore',
#     'iata': 'SIN',
#     'icao': 'WSSS',
#     'terminal': '3',
#     'gate': 'C22',
#     'delay': 10,
#     'scheduled': '2023-04-29T00:05:00+00:00',
#     'estimated': '2023-04-29T00:05:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Kastrup',
#     'timezone': 'Europe/Copenhagen',
#     'iata': 'CPH',
#     'icao': 'EKCH',
#     'terminal': '3',
#     'gate': None,
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2023-04-29T07:10:00+00:00',
#     'estimated': '2023-04-29T07:10:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'SAS', 'iata': 'SK', 'icao': 'SAS'},
#    'flight': {'number': '8000',
#     'iata': 'SK8000',
#     'icao': 'SAS8000',
#     'codeshared': {'airline_name': 'singapore airlines',
#      'airline_iata': 'sq',
#      'airline_icao': 'sia',
#      'flight_number': '352',
#      'flight_iata': 'sq352',
#      'flight_icao': 'sia352'}},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2023-04-29',
#    'flight_status': 'active',
#    'departure': {'airport': 'Singapore Changi',
#     'timezone': 'Asia/Singapore',
#     'iata': 'SIN',
#     'icao': 'WSSS',
#     'terminal': '3',
#     'gate': 'C22',
#     'delay': 10,
#     'scheduled': '2023-04-29T00:05:00+00:00',
#     'estimated': '2023-04-29T00:05:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Kastrup',
#     'timezone': 'Europe/Copenhagen',
#     'iata': 'CPH',
#     'icao': 'EKCH',
#     'terminal': '3',
#     'gate': None,
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2023-04-29T07:10:00+00:00',
#     'estimated': '2023-04-29T07:10:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Croatia Airlines', 'iata': 'OU', 'icao': 'CTN'},
#    'flight': {'number': '5807',
#     'iata': 'OU5807',
#     'icao': 'CTN5807',
#     'codeshared': {'airline_name': 'singapore airlines',
#      'airline_iata': 'sq',
#      'airline_icao': 'sia',
#      'flight_number': '352',
#      'flight_iata': 'sq352',
#      'flight_icao': 'sia352'}},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2023-04-29',
#    'flight_status': 'active',
#    'departure': {'airport': 'Singapore Changi',
#     'timezone': 'Asia/Singapore',
#     'iata': 'SIN',
#     'icao': 'WSSS',
#     'terminal': '3',
#     'gate': 'C22',
#     'delay': 10,
#     'scheduled': '2023-04-29T00:05:00+00:00',
#     'estimated': '2023-04-29T00:05:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Kastrup',
#     'timezone': 'Europe/Copenhagen',
#     'iata': 'CPH',
#     'icao': 'EKCH',
#     'terminal': '3',
#     'gate': None,
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2023-04-29T07:10:00+00:00',
#     'estimated': '2023-04-29T07:10:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Air New Zealand', 'iata': 'NZ', 'icao': 'ANZ'},
#    'flight': {'number': '3352',
#     'iata': 'NZ3352',
#     'icao': 'ANZ3352',
#     'codeshared': {'airline_name': 'singapore airlines',
#      'airline_iata': 'sq',
#      'airline_icao': 'sia',
#      'flight_number': '352',
#      'flight_iata': 'sq352',
#      'flight_icao': 'sia352'}},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2023-04-29',
#    'flight_status': 'active',
#    'departure': {'airport': 'Singapore Changi',
#     'timezone': 'Asia/Singapore',
#     'iata': 'SIN',
#     'icao': 'WSSS',
#     'terminal': '3',
#     'gate': 'C22',
#     'delay': 10,
#     'scheduled': '2023-04-29T00:05:00+00:00',
#     'estimated': '2023-04-29T00:05:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Kastrup',
#     'timezone': 'Europe/Copenhagen',
#     'iata': 'CPH',
#     'icao': 'EKCH',
#     'terminal': '3',
#     'gate': None,
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2023-04-29T07:10:00+00:00',
#     'estimated': '2023-04-29T07:10:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#    'flight': {'number': '5856',
#     'iata': 'MH5856',
#     'icao': 'MAS5856',
#     'codeshared': {'airline_name': 'singapore airlines',
#      'airline_iata': 'sq',
#      'airline_icao': 'sia',
#      'flight_number': '352',
#      'flight_iata': 'sq352',
#      'flight_icao': 'sia352'}},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2023-04-29',
#    'flight_status': 'scheduled',
#    'departure': {'airport': 'Shanghai Pudong International',
#     'timezone': 'Asia/Shanghai',
#     'iata': 'PVG',
#     'icao': 'ZSPD',
#     'terminal': None,
#     'gate': None,
#     'delay': 10,
#     'scheduled': '2023-04-29T04:40:00+00:00',
#     'estimated': '2023-04-29T04:40:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Charles De Gaulle',
#     'timezone': 'Europe/Paris',
#     'iata': 'CDG',
#     'icao': 'LFPG',
#     'terminal': None,
#     'gate': None,
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2023-04-29T12:18:00+00:00',
#     'estimated': '2023-04-29T12:18:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'FedEx', 'iata': 'FX', 'icao': 'FDX'},
#    'flight': {'number': '5170',
#     'iata': 'FX5170',
#     'icao': 'FDX5170',
#     'codeshared': None},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2023-04-29',
#    'flight_status': 'scheduled',
#    'departure': {'airport': 'Antalya',
#     'timezone': 'Europe/Istanbul',
#     'iata': 'AYT',
#     'icao': 'LTAI',
#     'terminal': '2',
#     'gate': None,
#     'delay': None,
#     'scheduled': '2023-04-29T00:40:00+00:00',
#     'estimated': '2023-04-29T00:40:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Koltsovo International',
#     'timezone': 'Asia/Yekaterinburg',
#     'iata': 'SVX',
#     'icao': 'USSS',
#     'terminal': None,
#     'gate': None,
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2023-04-29T07:30:00+00:00',
#     'estimated': '2023-04-29T07:30:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Aeroflot', 'iata': 'SU', 'icao': 'AFL'},
#    'flight': {'number': '793',
#     'iata': 'SU793',
#     'icao': 'AFL793',
#     'codeshared': None},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2023-04-29',
#    'flight_status': 'scheduled',
#    'departure': {'airport': 'Antalya',
#     'timezone': 'Europe/Istanbul',
#     'iata': 'AYT',
#     'icao': 'LTAI',
#     'terminal': '1',
#     'gate': None,
#     'delay': None,
#     'scheduled': '2023-04-29T00:35:00+00:00',
#     'estimated': '2023-04-29T00:35:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Ben Gurion International',
#     'timezone': 'Asia/Jerusalem',
#     'iata': 'TLV',
#     'icao': 'LLBG',
#     'terminal': '3',
#     'gate': None,
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2023-04-29T02:05:00+00:00',
#     'estimated': '2023-04-29T02:05:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Pegasus', 'iata': 'PC', 'icao': 'PGT'},
#    'flight': {'number': '787',
#     'iata': 'PC787',
#     'icao': 'PGT787',
#     'codeshared': None},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2023-04-29',
#    'flight_status': 'scheduled',
#    'departure': {'airport': 'Antalya',
#     'timezone': 'Europe/Istanbul',
#     'iata': 'AYT',
#     'icao': 'LTAI',
#     'terminal': '1',
#     'gate': None,
#     'delay': None,
#     'scheduled': '2023-04-29T00:30:00+00:00',
#     'estimated': '2023-04-29T00:30:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Ben Gurion International',
#     'timezone': 'Asia/Jerusalem',
#     'iata': 'TLV',
#     'icao': 'LLBG',
#     'terminal': None,
#     'gate': None,
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2023-04-29T02:00:00+00:00',
#     'estimated': '2023-04-29T02:00:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Corendon Air', 'iata': 'XC', 'icao': 'CAI'},
#    'flight': {'number': '431',
#     'iata': 'XC431',
#     'icao': 'CAI431',
#     'codeshared': None},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2023-04-29',
#    'flight_status': 'scheduled',
#    'departure': {'airport': 'Koltsovo International',
#     'timezone': 'Asia/Yekaterinburg',
#     'iata': 'SVX',
#     'icao': 'USSS',
#     'terminal': None,
#     'gate': None,
#     'delay': None,
#     'scheduled': '2023-04-29T00:45:00+00:00',
#     'estimated': '2023-04-29T00:45:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Kazan',
#     'timezone': 'Europe/Moscow',
#     'iata': 'KZN',
#     'icao': 'UWKD',
#     'terminal': '1A 2',
#     'gate': None,
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2023-04-29T00:25:00+00:00',
#     'estimated': '2023-04-29T00:25:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Rossiya Airlines', 'iata': 'FV', 'icao': 'SDM'},
#    'flight': {'number': '1067',
#     'iata': 'FV1067',
#     'icao': 'SDM1067',
#     'codeshared': None},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2023-04-29',
#    'flight_status': 'scheduled',
#    'departure': {'airport': 'Sjamsudin Noor',
#     'timezone': 'Asia/Makassar',
#     'iata': 'BDJ',
#     'icao': 'WAOO',
#     'terminal': None,
#     'gate': None,
#     'delay': None,
#     'scheduled': '2023-04-29T06:00:00+00:00',
#     'estimated': '2023-04-29T06:00:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Soekarno-Hatta International',
#     'timezone': 'Asia/Jakarta',
#     'iata': 'CGK',
#     'icao': 'WIII',
#     'terminal': '3',
#     'gate': None,
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2023-04-29T06:40:00+00:00',
#     'estimated': '2023-04-29T06:40:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Citilink', 'iata': 'QG', 'icao': 'CTV'},
#    'flight': {'number': '483',
#     'iata': 'QG483',
#     'icao': 'CTV483',
#     'codeshared': None},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2023-04-29',
#    'flight_status': 'scheduled',
#    'departure': {'airport': 'Sjamsudin Noor',
#     'timezone': 'Asia/Makassar',
#     'iata': 'BDJ',
#     'icao': 'WAOO',
#     'terminal': None,
#     'gate': None,
#     'delay': None,
#     'scheduled': '2023-04-29T06:00:00+00:00',
#     'estimated': '2023-04-29T06:00:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Soekarno-Hatta International',
#     'timezone': 'Asia/Jakarta',
#     'iata': 'CGK',
#     'icao': 'WIII',
#     'terminal': '2',
#     'gate': None,
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2023-04-29T06:40:00+00:00',
#     'estimated': '2023-04-29T06:40:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Batik Air', 'iata': 'ID', 'icao': 'BTK'},
#    'flight': {'number': '6211',
#     'iata': 'ID6211',
#     'icao': 'BTK6211',
#     'codeshared': None},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2023-04-29',
#    'flight_status': 'scheduled',
#    'departure': {'airport': 'Bukhara',
#     'timezone': 'Asia/Samarkand',
#     'iata': 'BHK',
#     'icao': 'UTSB',
#     'terminal': None,
#     'gate': None,
#     'delay': None,
#     'scheduled': '2023-04-29T02:50:00+00:00',
#     'estimated': '2023-04-29T02:50:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Vnukovo',
#     'timezone': 'Europe/Moscow',
#     'iata': 'VKO',
#     'icao': 'UUWW',
#     'terminal': 'A',
#     'gate': None,
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2023-04-29T05:10:00+00:00',
#     'estimated': '2023-04-29T05:10:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Qanot Sharq', 'iata': 'HH', 'icao': 'QNT'},
#    'flight': {'number': '775',
#     'iata': 'HH775',
#     'icao': 'QNT775',
#     'codeshared': None},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2023-04-29',
#    'flight_status': 'scheduled',
#    'departure': {'airport': 'Indira Gandhi International',
#     'timezone': 'Asia/Kolkata',
#     'iata': 'DEL',
#     'icao': 'VIDP',
#     'terminal': '3',
#     'gate': '19',
#     'delay': None,
#     'scheduled': '2023-04-29T00:35:00+00:00',
#     'estimated': '2023-04-29T00:35:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Charles De Gaulle',
#     'timezone': 'Europe/Paris',
#     'iata': 'CDG',
#     'icao': 'LFPG',
#     'terminal': '2E',
#     'gate': None,
#     'baggage': '32',
#     'delay': None,
#     'scheduled': '2023-04-29T07:00:00+00:00',
#     'estimated': '2023-04-29T07:00:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'KLM', 'iata': 'KL', 'icao': 'KLM'},
#    'flight': {'number': '2369',
#     'iata': 'KL2369',
#     'icao': 'KLM2369',
#     'codeshared': {'airline_name': 'air france',
#      'airline_iata': 'af',
#      'airline_icao': 'afr',
#      'flight_number': '225',
#      'flight_iata': 'af225',
#      'flight_icao': 'afr225'}},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2023-04-29',
#    'flight_status': 'scheduled',
#    'departure': {'airport': 'Indira Gandhi International',
#     'timezone': 'Asia/Kolkata',
#     'iata': 'DEL',
#     'icao': 'VIDP',
#     'terminal': '3',
#     'gate': '19',
#     'delay': None,
#     'scheduled': '2023-04-29T00:35:00+00:00',
#     'estimated': '2023-04-29T00:35:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Charles De Gaulle',
#     'timezone': 'Europe/Paris',
#     'iata': 'CDG',
#     'icao': 'LFPG',
#     'terminal': '2E',
#     'gate': None,
#     'baggage': '32',
#     'delay': None,
#     'scheduled': '2023-04-29T07:00:00+00:00',
#     'estimated': '2023-04-29T07:00:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Delta Air Lines', 'iata': 'DL', 'icao': 'DAL'},
#    'flight': {'number': '8649',
#     'iata': 'DL8649',
#     'icao': 'DAL8649',
#     'codeshared': {'airline_name': 'air france',
#      'airline_iata': 'af',
#      'airline_icao': 'afr',
#      'flight_number': '225',
#      'flight_iata': 'af225',
#      'flight_icao': 'afr225'}},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2023-04-29',
#    'flight_status': 'scheduled',
#    'departure': {'airport': 'Indira Gandhi International',
#     'timezone': 'Asia/Kolkata',
#     'iata': 'DEL',
#     'icao': 'VIDP',
#     'terminal': '3',
#     'gate': None,
#     'delay': None,
#     'scheduled': '2023-04-29T00:05:00+00:00',
#     'estimated': '2023-04-29T00:05:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Seoul (Incheon)',
#     'timezone': 'Asia/Seoul',
#     'iata': 'ICN',
#     'icao': 'RKSI',
#     'terminal': '1',
#     'gate': '35',
#     'baggage': '19',
#     'delay': None,
#     'scheduled': '2023-04-29T10:30:00+00:00',
#     'estimated': '2023-04-29T10:30:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Asiana Airlines', 'iata': 'OZ', 'icao': 'AAR'},
#    'flight': {'number': '6378',
#     'iata': 'OZ6378',
#     'icao': 'AAR6378',
#     'codeshared': {'airline_name': 'air india',
#      'airline_iata': 'ai',
#      'airline_icao': 'aic',
#      'flight_number': '312',
#      'flight_iata': 'ai312',
#      'flight_icao': 'aic312'}},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2023-04-29',
#    'flight_status': 'scheduled',
#    'departure': {'airport': 'Indira Gandhi International',
#     'timezone': 'Asia/Kolkata',
#     'iata': 'DEL',
#     'icao': 'VIDP',
#     'terminal': '3',
#     'gate': None,
#     'delay': None,
#     'scheduled': '2023-04-29T00:05:00+00:00',
#     'estimated': '2023-04-29T00:05:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Tan Son Nhat International',
#     'timezone': 'Asia/Ho_Chi_Minh',
#     'iata': 'SGN',
#     'icao': 'VVTS',
#     'terminal': '2',
#     'gate': None,
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2023-04-29T06:35:00+00:00',
#     'estimated': '2023-04-29T06:35:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': None, 'iata': 'H1', 'icao': 'H1'},
#    'flight': {'number': '4023',
#     'iata': 'H14023',
#     'icao': 'H14023',
#     'codeshared': {'airline_name': 'vietjet air',
#      'airline_iata': 'vj',
#      'airline_icao': 'vjc',
#      'flight_number': '896',
#      'flight_iata': 'vj896',
#      'flight_icao': 'vjc896'}},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2023-04-29',
#    'flight_status': 'scheduled',
#    'departure': {'airport': 'Indira Gandhi International',
#     'timezone': 'Asia/Kolkata',
#     'iata': 'DEL',
#     'icao': 'VIDP',
#     'terminal': '3',
#     'gate': None,
#     'delay': None,
#     'scheduled': '2023-04-29T00:05:00+00:00',
#     'estimated': '2023-04-29T00:05:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Tan Son Nhat International',
#     'timezone': 'Asia/Ho_Chi_Minh',
#     'iata': 'SGN',
#     'icao': 'VVTS',
#     'terminal': '2',
#     'gate': None,
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2023-04-29T06:35:00+00:00',
#     'estimated': '2023-04-29T06:35:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'FlexFlight', 'iata': 'W2', 'icao': 'FXT'},
#    'flight': {'number': '4896',
#     'iata': 'W24896',
#     'icao': 'FXT4896',
#     'codeshared': {'airline_name': 'vietjet air',
#      'airline_iata': 'vj',
#      'airline_icao': 'vjc',
#      'flight_number': '896',
#      'flight_iata': 'vj896',
#      'flight_icao': 'vjc896'}},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2023-04-29',
#    'flight_status': 'scheduled',
#    'departure': {'airport': 'Indira Gandhi International',
#     'timezone': 'Asia/Kolkata',
#     'iata': 'DEL',
#     'icao': 'VIDP',
#     'terminal': '3',
#     'gate': None,
#     'delay': None,
#     'scheduled': '2023-04-29T00:05:00+00:00',
#     'estimated': '2023-04-29T00:05:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Tan Son Nhat International',
#     'timezone': 'Asia/Ho_Chi_Minh',
#     'iata': 'SGN',
#     'icao': 'VVTS',
#     'terminal': '2',
#     'gate': None,
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2023-04-29T06:35:00+00:00',
#     'estimated': '2023-04-29T06:35:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': None, 'iata': 'A1', 'icao': 'A1'},
#    'flight': {'number': '2896',
#     'iata': 'A12896',
#     'icao': 'A12896',
#     'codeshared': {'airline_name': 'vietjet air',
#      'airline_iata': 'vj',
#      'airline_icao': 'vjc',
#      'flight_number': '896',
#      'flight_iata': 'vj896',
#      'flight_icao': 'vjc896'}},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2023-04-29',
#    'flight_status': 'scheduled',
#    'departure': {'airport': 'Shenzhen',
#     'timezone': 'Asia/Shanghai',
#     'iata': 'SZX',
#     'icao': 'ZGSZ',
#     'terminal': None,
#     'gate': None,
#     'delay': None,
#     'scheduled': '2023-04-29T05:05:00+00:00',
#     'estimated': '2023-04-29T05:05:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Ted Stevens Anchorage International Airport',
#     'timezone': 'America/Anchorage',
#     'iata': 'ANC',
#     'icao': 'PANC',
#     'terminal': None,
#     'gate': None,
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2023-04-28T22:56:00+00:00',
#     'estimated': '2023-04-28T22:56:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'UPS Airlines', 'iata': '5X', 'icao': 'UPS'},
#    'flight': {'number': '71',
#     'iata': '5X71',
#     'icao': 'UPS71',
#     'codeshared': None},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2023-04-29',
#    'flight_status': 'scheduled',
#    'departure': {'airport': 'Shenzhen',
#     'timezone': 'Asia/Shanghai',
#     'iata': 'SZX',
#     'icao': 'ZGSZ',
#     'terminal': None,
#     'gate': None,
#     'delay': None,
#     'scheduled': '2023-04-29T05:05:00+00:00',
#     'estimated': '2023-04-29T05:05:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Beijing Capital International',
#     'timezone': 'Asia/Shanghai',
#     'iata': 'PEK',
#     'icao': 'ZBAA',
#     'terminal': None,
#     'gate': None,
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2023-04-29T08:15:00+00:00',
#     'estimated': '2023-04-29T08:15:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'China Postal Airlines', 'iata': 'CF', 'icao': 'CYZ'},
#    'flight': {'number': '9090',
#     'iata': 'CF9090',
#     'icao': 'CYZ9090',
#     'codeshared': None},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2023-04-29',
#    'flight_status': 'scheduled',
#    'departure': {'airport': 'Shenzhen',
#     'timezone': 'Asia/Shanghai',
#     'iata': 'SZX',
#     'icao': 'ZGSZ',
#     'terminal': None,
#     'gate': None,
#     'delay': None,
#     'scheduled': '2023-04-29T05:00:00+00:00',
#     'estimated': '2023-04-29T05:00:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Shenyang',
#     'timezone': 'Asia/Shanghai',
#     'iata': 'SHE',
#     'icao': 'ZYTX',
#     'terminal': None,
#     'gate': None,
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2023-04-29T08:50:00+00:00',
#     'estimated': '2023-04-29T08:50:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'SF Airlines', 'iata': 'O3', 'icao': 'CSS'},
#    'flight': {'number': '7333',
#     'iata': 'O37333',
#     'icao': 'CSS7333',
#     'codeshared': None},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2023-04-29',
#    'flight_status': 'scheduled',
#    'departure': {'airport': 'Shenzhen',
#     'timezone': 'Asia/Shanghai',
#     'iata': 'SZX',
#     'icao': 'ZGSZ',
#     'terminal': None,
#     'gate': None,
#     'delay': None,
#     'scheduled': '2023-04-29T04:55:00+00:00',
#     'estimated': '2023-04-29T04:55:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Noibai International',
#     'timezone': 'Asia/Ho_Chi_Minh',
#     'iata': 'HAN',
#     'icao': 'VVNB',
#     'terminal': None,
#     'gate': None,
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2023-04-29T05:55:00+00:00',
#     'estimated': '2023-04-29T05:55:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Shandong Airlines', 'iata': 'SC', 'icao': 'CDG'},
#    'flight': {'number': '2482',
#     'iata': 'SC2482',
#     'icao': 'CDG2482',
#     'codeshared': None},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2023-04-29',
#    'flight_status': 'scheduled',
#    'departure': {'airport': 'Shenzhen',
#     'timezone': 'Asia/Shanghai',
#     'iata': 'SZX',
#     'icao': 'ZGSZ',
#     'terminal': None,
#     'gate': None,
#     'delay': None,
#     'scheduled': '2023-04-29T04:50:00+00:00',
#     'estimated': '2023-04-29T04:50:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Madras International (Meenambakkam)',
#     'timezone': 'Asia/Kolkata',
#     'iata': 'MAA',
#     'icao': 'VOMM',
#     'terminal': None,
#     'gate': None,
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2023-04-29T08:45:00+00:00',
#     'estimated': '2023-04-29T08:45:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'SF Airlines', 'iata': 'O3', 'icao': 'CSS'},
#    'flight': {'number': '7637',
#     'iata': 'O37637',
#     'icao': 'CSS7637',
#     'codeshared': None},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2023-04-29',
#    'flight_status': 'scheduled',
#    'departure': {'airport': 'Shenzhen',
#     'timezone': 'Asia/Shanghai',
#     'iata': 'SZX',
#     'icao': 'ZGSZ',
#     'terminal': None,
#     'gate': None,
#     'delay': None,
#     'scheduled': '2023-04-29T04:40:00+00:00',
#     'estimated': '2023-04-29T04:40:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Manas (Bishkek)',
#     'timezone': 'Asia/Bishkek',
#     'iata': 'FRU',
#     'icao': 'UCFM',
#     'terminal': None,
#     'gate': None,
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2023-04-29T09:35:00+00:00',
#     'estimated': '2023-04-29T09:35:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Turkish Airlines', 'iata': 'TK', 'icao': 'THY'},
#    'flight': {'number': '6237',
#     'iata': 'TK6237',
#     'icao': 'THY6237',
#     'codeshared': None},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2023-04-29',
#    'flight_status': 'scheduled',
#    'departure': {'airport': 'Shenzhen',
#     'timezone': 'Asia/Shanghai',
#     'iata': 'SZX',
#     'icao': 'ZGSZ',
#     'terminal': None,
#     'gate': None,
#     'delay': None,
#     'scheduled': '2023-04-29T04:30:00+00:00',
#     'estimated': '2023-04-29T04:30:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Beijing Capital International',
#     'timezone': 'Asia/Shanghai',
#     'iata': 'PEK',
#     'icao': 'ZBAA',
#     'terminal': None,
#     'gate': None,
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2023-04-29T07:45:00+00:00',
#     'estimated': '2023-04-29T07:45:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'SF Airlines', 'iata': 'O3', 'icao': 'CSS'},
#    'flight': {'number': '7106',
#     'iata': 'O37106',
#     'icao': 'CSS7106',
#     'codeshared': None},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2023-04-29',
#    'flight_status': 'scheduled',
#    'departure': {'airport': 'Shenzhen',
#     'timezone': 'Asia/Shanghai',
#     'iata': 'SZX',
#     'icao': 'ZGSZ',
#     'terminal': None,
#     'gate': None,
#     'delay': None,
#     'scheduled': '2023-04-29T04:30:00+00:00',
#     'estimated': '2023-04-29T04:30:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Phnom Penh International',
#     'timezone': 'Asia/Phnom_Penh',
#     'iata': 'PNH',
#     'icao': 'VDPP',
#     'terminal': None,
#     'gate': None,
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2023-04-29T06:20:00+00:00',
#     'estimated': '2023-04-29T06:20:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Cambodia Airways', 'iata': 'KR', 'icao': 'KME'},
#    'flight': {'number': '930',
#     'iata': 'KR930',
#     'icao': 'KME930',
#     'codeshared': None},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2023-04-29',
#    'flight_status': 'scheduled',
#    'departure': {'airport': 'Shenzhen',
#     'timezone': 'Asia/Shanghai',
#     'iata': 'SZX',
#     'icao': 'ZGSZ',
#     'terminal': None,
#     'gate': None,
#     'delay': None,
#     'scheduled': '2023-04-29T04:25:00+00:00',
#     'estimated': '2023-04-29T04:25:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Nanjing Lukou International Airport',
#     'timezone': 'Asia/Shanghai',
#     'iata': 'NKG',
#     'icao': 'ZSNJ',
#     'terminal': None,
#     'gate': None,
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2023-04-29T06:55:00+00:00',
#     'estimated': '2023-04-29T06:55:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'SF Airlines', 'iata': 'O3', 'icao': 'CSS'},
#    'flight': {'number': '6944',
#     'iata': 'O36944',
#     'icao': 'CSS6944',
#     'codeshared': None},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2023-04-29',
#    'flight_status': 'scheduled',
#    'departure': {'airport': 'Shenzhen',
#     'timezone': 'Asia/Shanghai',
#     'iata': 'SZX',
#     'icao': 'ZGSZ',
#     'terminal': None,
#     'gate': None,
#     'delay': None,
#     'scheduled': '2023-04-29T04:10:00+00:00',
#     'estimated': '2023-04-29T04:10:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Suvarnabhumi International',
#     'timezone': 'Asia/Bangkok',
#     'iata': 'BKK',
#     'icao': 'VTBS',
#     'terminal': None,
#     'gate': None,
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2023-04-29T06:10:00+00:00',
#     'estimated': '2023-04-29T06:10:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Central Airlines', 'iata': 'I9', 'icao': 'HLF'},
#    'flight': {'number': '9811',
#     'iata': 'I99811',
#     'icao': 'HLF9811',
#     'codeshared': None},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2023-04-29',
#    'flight_status': 'scheduled',
#    'departure': {'airport': 'Shenzhen',
#     'timezone': 'Asia/Shanghai',
#     'iata': 'SZX',
#     'icao': 'ZGSZ',
#     'terminal': None,
#     'gate': None,
#     'delay': None,
#     'scheduled': '2023-04-29T04:10:00+00:00',
#     'estimated': '2023-04-29T04:10:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Francisco Bangoy International',
#     'timezone': 'Asia/Manila',
#     'iata': 'DVO',
#     'icao': 'RPMD',
#     'terminal': None,
#     'gate': None,
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2023-04-29T07:10:00+00:00',
#     'estimated': '2023-04-29T07:10:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Central Airlines', 'iata': 'I9', 'icao': 'HLF'},
#    'flight': {'number': '9813',
#     'iata': 'I99813',
#     'icao': 'HLF9813',
#     'codeshared': None},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2023-04-29',
#    'flight_status': 'scheduled',
#    'departure': {'airport': 'Melbourne - Tullamarine Airport',
#     'timezone': 'Australia/Melbourne',
#     'iata': 'MEL',
#     'icao': 'YMML',
#     'terminal': '1',
#     'gate': None,
#     'delay': None,
#     'scheduled': '2023-04-29T08:05:00+00:00',
#     'estimated': '2023-04-29T08:05:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Canberra',
#     'timezone': 'Australia/Sydney',
#     'iata': 'CBR',
#     'icao': 'YSCB',
#     'terminal': None,
#     'gate': '11',
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2023-04-29T09:10:00+00:00',
#     'estimated': '2023-04-29T09:10:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Emirates', 'iata': 'EK', 'icao': 'UAE'},
#    'flight': {'number': '5479',
#     'iata': 'EK5479',
#     'icao': 'UAE5479',
#     'codeshared': {'airline_name': 'qantas',
#      'airline_iata': 'qf',
#      'airline_icao': 'qfa',
#      'flight_number': '1514',
#      'flight_iata': 'qf1514',
#      'flight_icao': 'qfa1514'}},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2023-04-29',
#    'flight_status': 'scheduled',
#    'departure': {'airport': 'Melbourne - Tullamarine Airport',
#     'timezone': 'Australia/Melbourne',
#     'iata': 'MEL',
#     'icao': 'YMML',
#     'terminal': '1',
#     'gate': None,
#     'delay': None,
#     'scheduled': '2023-04-29T08:05:00+00:00',
# ...
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'ANA', 'iata': 'NH', 'icao': 'ANA'},
#    'flight': {'number': '381',
#     'iata': 'NH381',
#     'icao': 'ANA381',
#     'codeshared': None},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2023-04-29',
#    'flight_status': 'scheduled',
#    'departure': {'airport': 'Haneda Airport',
#     'timezone': 'Asia/Tokyo',
#     'iata': 'HND',
#     'icao': 'RJTT',
#     'terminal': '1',
#     'gate': '10',
#     'delay': None,
#     'scheduled': '2023-04-29T06:55:00+00:00',
#     'estimated': '2023-04-29T06:55:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Kansai International',
#     'timezone': 'Asia/Tokyo',
#     'iata': 'KIX',
#     'icao': 'RJBB',
#     'terminal': '1',
#     'gate': '40',
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2023-04-29T08:15:00+00:00',
#     'estimated': '2023-04-29T08:15:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'JAL', 'iata': 'JL', 'icao': 'JAL'},
#    'flight': {'number': '221',
#     'iata': 'JL221',
#     'icao': 'JAL221',
#     'codeshared': None},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2023-04-29',
#    'flight_status': 'scheduled',
#    'departure': {'airport': 'Haneda Airport',
#     'timezone': 'Asia/Tokyo',
#     'iata': 'HND',
#     'icao': 'RJTT',
#     'terminal': '1',
#     'gate': '10',
#     'delay': None,
#     'scheduled': '2023-04-29T06:55:00+00:00',
#     'estimated': '2023-04-29T06:55:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Kansai International',
#     'timezone': 'Asia/Tokyo',
#     'iata': 'KIX',
#     'icao': 'RJBB',
#     'terminal': '1',
#     'gate': '40',
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2023-04-29T08:15:00+00:00',
#     'estimated': '2023-04-29T08:15:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Malaysia Airlines', 'iata': 'MH', 'icao': 'MAS'},
#    'flight': {'number': '9167',
#     'iata': 'MH9167',
#     'icao': 'MAS9167',
#     'codeshared': {'airline_name': 'jal',
#      'airline_iata': 'jl',
#      'airline_icao': 'jal',
#      'flight_number': '221',
#      'flight_iata': 'jl221',
#      'flight_icao': 'jal221'}},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2023-04-29',
#    'flight_status': 'scheduled',
#    'departure': {'airport': 'Haneda Airport',
#     'timezone': 'Asia/Tokyo',
#     'iata': 'HND',
#     'icao': 'RJTT',
#     'terminal': '1',
#     'gate': '10',
#     'delay': None,
#     'scheduled': '2023-04-29T06:55:00+00:00',
#     'estimated': '2023-04-29T06:55:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Kansai International',
#     'timezone': 'Asia/Tokyo',
#     'iata': 'KIX',
#     'icao': 'RJBB',
#     'terminal': '1',
#     'gate': '40',
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2023-04-29T08:15:00+00:00',
#     'estimated': '2023-04-29T08:15:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Qatar Airways', 'iata': 'QR', 'icao': 'QTR'},
#    'flight': {'number': '6045',
#     'iata': 'QR6045',
#     'icao': 'QTR6045',
#     'codeshared': {'airline_name': 'jal',
#      'airline_iata': 'jl',
#      'airline_icao': 'jal',
#      'flight_number': '221',
#      'flight_iata': 'jl221',
#      'flight_icao': 'jal221'}},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2023-04-29',
#    'flight_status': 'scheduled',
#    'departure': {'airport': 'Haneda Airport',
#     'timezone': 'Asia/Tokyo',
#     'iata': 'HND',
#     'icao': 'RJTT',
#     'terminal': '1',
#     'gate': '10',
#     'delay': None,
#     'scheduled': '2023-04-29T06:55:00+00:00',
#     'estimated': '2023-04-29T06:55:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Kansai International',
#     'timezone': 'Asia/Tokyo',
#     'iata': 'KIX',
#     'icao': 'RJBB',
#     'terminal': '1',
#     'gate': '40',
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2023-04-29T08:15:00+00:00',
#     'estimated': '2023-04-29T08:15:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Hawaiian Airlines', 'iata': 'HA', 'icao': 'HAL'},
#    'flight': {'number': '5085',
#     'iata': 'HA5085',
#     'icao': 'HAL5085',
#     'codeshared': {'airline_name': 'jal',
#      'airline_iata': 'jl',
#      'airline_icao': 'jal',
#      'flight_number': '221',
#      'flight_iata': 'jl221',
#      'flight_icao': 'jal221'}},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2023-04-29',
#    'flight_status': 'scheduled',
#    'departure': {'airport': 'Haneda Airport',
#     'timezone': 'Asia/Tokyo',
#     'iata': 'HND',
#     'icao': 'RJTT',
#     'terminal': '2',
#     'gate': '500',
#     'delay': None,
#     'scheduled': '2023-04-29T06:55:00+00:00',
#     'estimated': '2023-04-29T06:55:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Obihiro',
#     'timezone': 'Asia/Tokyo',
#     'iata': 'OBO',
#     'icao': 'RJCB',
#     'terminal': None,
#     'gate': None,
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2023-04-29T08:25:00+00:00',
#     'estimated': '2023-04-29T08:25:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Air Do', 'iata': 'HD', 'icao': 'ADO'},
#    'flight': {'number': '61',
#     'iata': 'HD61',
#     'icao': 'ADO61',
#     'codeshared': None},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2023-04-29',
#    'flight_status': 'scheduled',
#    'departure': {'airport': 'Haneda Airport',
#     'timezone': 'Asia/Tokyo',
#     'iata': 'HND',
#     'icao': 'RJTT',
#     'terminal': '2',
#     'gate': '500',
#     'delay': None,
#     'scheduled': '2023-04-29T06:55:00+00:00',
#     'estimated': '2023-04-29T06:55:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Obihiro',
#     'timezone': 'Asia/Tokyo',
#     'iata': 'OBO',
#     'icao': 'RJCB',
#     'terminal': None,
#     'gate': None,
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2023-04-29T08:25:00+00:00',
#     'estimated': '2023-04-29T08:25:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'ANA', 'iata': 'NH', 'icao': 'ANA'},
#    'flight': {'number': '4761',
#     'iata': 'NH4761',
#     'icao': 'ANA4761',
#     'codeshared': {'airline_name': 'air do',
#      'airline_iata': 'hd',
#      'airline_icao': 'ado',
#      'flight_number': '61',
#      'flight_iata': 'hd61',
#      'flight_icao': 'ado61'}},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2023-04-29',
#    'flight_status': 'scheduled',
#    'departure': {'airport': 'Haneda Airport',
#     'timezone': 'Asia/Tokyo',
#     'iata': 'HND',
#     'icao': 'RJTT',
#     'terminal': '2',
#     'gate': '55',
#     'delay': None,
#     'scheduled': '2023-04-29T06:55:00+00:00',
#     'estimated': '2023-04-29T06:55:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Chitose',
#     'timezone': 'Asia/Tokyo',
#     'iata': 'CTS',
#     'icao': 'RJCC',
#     'terminal': 'D',
#     'gate': None,
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2023-04-29T08:25:00+00:00',
#     'estimated': '2023-04-29T08:25:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Air Do', 'iata': 'HD', 'icao': 'ADO'},
#    'flight': {'number': '11',
#     'iata': 'HD11',
#     'icao': 'ADO11',
#     'codeshared': None},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2023-04-29',
#    'flight_status': 'scheduled',
#    'departure': {'airport': 'Haneda Airport',
#     'timezone': 'Asia/Tokyo',
#     'iata': 'HND',
#     'icao': 'RJTT',
#     'terminal': '2',
#     'gate': '55',
#     'delay': None,
#     'scheduled': '2023-04-29T06:55:00+00:00',
#     'estimated': '2023-04-29T06:55:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Chitose',
#     'timezone': 'Asia/Tokyo',
#     'iata': 'CTS',
#     'icao': 'RJCC',
#     'terminal': 'D',
#     'gate': None,
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2023-04-29T08:25:00+00:00',
#     'estimated': '2023-04-29T08:25:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'ANA', 'iata': 'NH', 'icao': 'ANA'},
#    'flight': {'number': '4711',
#     'iata': 'NH4711',
#     'icao': 'ANA4711',
#     'codeshared': {'airline_name': 'air do',
#      'airline_iata': 'hd',
#      'airline_icao': 'ado',
#      'flight_number': '11',
#      'flight_iata': 'hd11',
#      'flight_icao': 'ado11'}},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2023-04-29',
#    'flight_status': 'scheduled',
#    'departure': {'airport': 'Haneda Airport',
#     'timezone': 'Asia/Tokyo',
#     'iata': 'HND',
#     'icao': 'RJTT',
#     'terminal': '2',
#     'gate': '53',
#     'delay': None,
#     'scheduled': '2023-04-29T06:50:00+00:00',
#     'estimated': '2023-04-29T06:50:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Miyazaki',
#     'timezone': 'Asia/Tokyo',
#     'iata': 'KMI',
#     'icao': 'RJFM',
#     'terminal': None,
#     'gate': None,
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2023-04-29T08:35:00+00:00',
#     'estimated': '2023-04-29T08:35:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Solaseed Air', 'iata': '6J', 'icao': 'SNJ'},
#    'flight': {'number': '51',
#     'iata': '6J51',
#     'icao': 'SNJ51',
#     'codeshared': None},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2023-04-29',
#    'flight_status': 'scheduled',
#    'departure': {'airport': 'Haneda Airport',
#     'timezone': 'Asia/Tokyo',
#     'iata': 'HND',
#     'icao': 'RJTT',
#     'terminal': '2',
#     'gate': '53',
#     'delay': None,
#     'scheduled': '2023-04-29T06:50:00+00:00',
#     'estimated': '2023-04-29T06:50:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Miyazaki',
#     'timezone': 'Asia/Tokyo',
#     'iata': 'KMI',
#     'icao': 'RJFM',
#     'terminal': None,
#     'gate': None,
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2023-04-29T08:35:00+00:00',
#     'estimated': '2023-04-29T08:35:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'ANA', 'iata': 'NH', 'icao': 'ANA'},
#    'flight': {'number': '2451',
#     'iata': 'NH2451',
#     'icao': 'ANA2451',
#     'codeshared': {'airline_name': 'solaseed air',
#      'airline_iata': '6j',
#      'airline_icao': 'snj',
#      'flight_number': '51',
#      'flight_iata': '6j51',
#      'flight_icao': 'snj51'}},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2023-04-29',
#    'flight_status': 'scheduled',
#    'departure': {'airport': 'Haneda Airport',
#     'timezone': 'Asia/Tokyo',
#     'iata': 'HND',
#     'icao': 'RJTT',
#     'terminal': '2',
#     'gate': '67B',
#     'delay': None,
#     'scheduled': '2023-04-29T06:45:00+00:00',
#     'estimated': '2023-04-29T06:45:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': None,
#     'timezone': None,
#     'iata': 'IWK',
#     'icao': 'RJOI',
#     'terminal': None,
#     'gate': None,
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2023-04-29T08:20:00+00:00',
#     'estimated': '2023-04-29T08:20:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'ANA', 'iata': 'NH', 'icao': 'ANA'},
#    'flight': {'number': '631',
#     'iata': 'NH631',
#     'icao': 'ANA631',
#     'codeshared': None},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2023-04-29',
#    'flight_status': 'scheduled',
#    'departure': {'airport': 'Haneda Airport',
#     'timezone': 'Asia/Tokyo',
#     'iata': 'HND',
#     'icao': 'RJTT',
#     'terminal': '2',
#     'gate': '67B',
#     'delay': None,
#     'scheduled': '2023-04-29T06:45:00+00:00',
#     'estimated': '2023-04-29T06:45:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': None,
#     'timezone': None,
#     'iata': 'IWK',
#     'icao': 'RJOI',
#     'terminal': None,
#     'gate': None,
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2023-04-29T08:20:00+00:00',
#     'estimated': '2023-04-29T08:20:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Philippine Airlines', 'iata': 'PR', 'icao': 'PAL'},
#    'flight': {'number': '3182',
#     'iata': 'PR3182',
#     'icao': 'PAL3182',
#     'codeshared': {'airline_name': 'ana',
#      'airline_iata': 'nh',
#      'airline_icao': 'ana',
#      'flight_number': '631',
#      'flight_iata': 'nh631',
#      'flight_icao': 'ana631'}},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2023-04-29',
#    'flight_status': 'scheduled',
#    'departure': {'airport': 'Haneda Airport',
#     'timezone': 'Asia/Tokyo',
#     'iata': 'HND',
#     'icao': 'RJTT',
#     'terminal': '2',
#     'gate': '509',
#     'delay': None,
#     'scheduled': '2023-04-29T06:45:00+00:00',
#     'estimated': '2023-04-29T06:45:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Tottori',
#     'timezone': 'Asia/Tokyo',
#     'iata': 'TTJ',
#     'icao': 'RJOR',
#     'terminal': None,
#     'gate': None,
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2023-04-29T08:00:00+00:00',
#     'estimated': '2023-04-29T08:00:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'ANA', 'iata': 'NH', 'icao': 'ANA'},
#    'flight': {'number': '291',
#     'iata': 'NH291',
#     'icao': 'ANA291',
#     'codeshared': None},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2023-04-29',
#    'flight_status': 'scheduled',
#    'departure': {'airport': 'Haneda Airport',
#     'timezone': 'Asia/Tokyo',
#     'iata': 'HND',
#     'icao': 'RJTT',
#     'terminal': '1',
#     'gate': None,
#     'delay': None,
#     'scheduled': '2023-04-29T06:45:00+00:00',
#     'estimated': '2023-04-29T06:45:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Chitose',
#     'timezone': 'Asia/Tokyo',
#     'iata': 'CTS',
#     'icao': 'RJCC',
#     'terminal': 'D',
#     'gate': None,
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2023-04-29T08:20:00+00:00',
#     'estimated': '2023-04-29T08:20:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'Skymark Airlines', 'iata': 'BC', 'icao': 'SKY'},
#    'flight': {'number': '703',
#     'iata': 'BC703',
#     'icao': 'SKY703',
#     'codeshared': None},
#    'aircraft': None,
#    'live': None},
#   {'flight_date': '2023-04-29',
#    'flight_status': 'scheduled',
#    'departure': {'airport': 'Haneda Airport',
#     'timezone': 'Asia/Tokyo',
#     'iata': 'HND',
#     'icao': 'RJTT',
#     'terminal': '2',
#     'gate': None,
#     'delay': None,
#     'scheduled': '2023-04-29T06:45:00+00:00',
#     'estimated': '2023-04-29T06:45:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'arrival': {'airport': 'Kagoshima',
#     'timezone': 'Asia/Tokyo',
#     'iata': 'KOJ',
#     'icao': 'RJFK',
#     'terminal': None,
#     'gate': None,
#     'baggage': None,
#     'delay': None,
#     'scheduled': '2023-04-29T08:35:00+00:00',
#     'estimated': '2023-04-29T08:35:00+00:00',
#     'actual': None,
#     'estimated_runway': None,
#     'actual_runway': None},
#    'airline': {'name': 'ANA', 'iata': 'NH', 'icao': 'ANA'},
#    'flight': {'number': '619',
#     'iata': 'NH619',
#     'icao': 'ANA619',
#     'codeshared': None},
#    'aircraft': None,
#    'live': None}]}

# %% [markdown]
# ## 3. Cleaning DataFrame

# %%
df = pd.DataFrame(api_response["data"])
df
# Out:
#    flight_date flight_status
# 0   2023-04-29     scheduled  \
# 1   2023-04-29     scheduled
# 2   2023-04-29     scheduled
# 3   2023-04-29     scheduled
# 4   2023-04-29     scheduled
# ..         ...           ...
# 95  2023-04-29     scheduled
# 96  2023-04-29     scheduled
# 97  2023-04-29     scheduled
# 98  2023-04-29     scheduled
# 99  2023-04-29     scheduled
#
#                                             departure
# 0   {'airport': 'Queen Alia International', 'timez...  \
# 1   {'airport': 'Queen Alia International', 'timez...
# 2   {'airport': 'Queen Alia International', 'timez...
# 3   {'airport': 'Queen Alia International', 'timez...
# 4   {'airport': 'Queen Alia International', 'timez...
# ..                                                ...
# 95  {'airport': 'Jomo Kenyatta International', 'ti...
# 96  {'airport': 'Jomo Kenyatta International', 'ti...
# 97  {'airport': 'Jomo Kenyatta International', 'ti...
# 98  {'airport': 'Jomo Kenyatta International', 'ti...
# 99  {'airport': 'Yuzhno-Sakhalinsk', 'timezone': '...
#
#                                               arrival
# 0   {'airport': 'King Fahd International Airport',...  \
# 1   {'airport': 'King Fahd International Airport',...
# 2   {'airport': 'Erbil International (irbil Northw...
# 3   {'airport': 'Doha International', 'timezone': ...
# 4   {'airport': 'Doha International', 'timezone': ...
# ..                                                ...
# 95  {'airport': 'King Abdulaziz International', 't...
# 96  {'airport': 'King Abdulaziz International', 't...
# 97  {'airport': 'Heathrow', 'timezone': 'Europe/Lo...
# 98  {'airport': 'Heathrow', 'timezone': 'Europe/Lo...
# 99  {'airport': None, 'timezone': None, 'iata': 'N...
#
#                                               airline
# 0     {'name': 'flynas', 'iata': 'XY', 'icao': 'KNE'}  \
# 1   {'name': 'Ethiopian Airlines', 'iata': 'ET', '...
# 2   {'name': 'Royal Jordanian', 'iata': 'RJ', 'ica...
# 3   {'name': 'Royal Jordanian', 'iata': 'RJ', 'ica...
# 4   {'name': 'Qatar Airways', 'iata': 'QR', 'icao'...
# ..                                                ...
# 95    {'name': 'Saudia', 'iata': 'SV', 'icao': 'SVA'}
# 96  {'name': 'Kenya Airways', 'iata': 'KQ', 'icao'...
# 97  {'name': 'Kenya Airways', 'iata': 'KQ', 'icao'...
# 98  {'name': 'Delta Air Lines', 'iata': 'DL', 'ica...
# 99    {'name': 'Aurora', 'iata': 'HZ', 'icao': 'SHU'}
#
#                                                flight aircraft  live
# 0   {'number': '832', 'iata': 'XY832', 'icao': 'KN...     None  None
# 1   {'number': '4511', 'iata': 'ET4511', 'icao': '...     None  None
# 2   {'number': '824', 'iata': 'RJ824', 'icao': 'RJ...     None  None
# 3   {'number': '650', 'iata': 'RJ650', 'icao': 'RJ...     None  None
# 4   {'number': '6101', 'iata': 'QR6101', 'icao': '...     None  None
# ..                                                ...      ...   ...
# 95  {'number': '430', 'iata': 'SV430', 'icao': 'SV...     None  None
# 96  {'number': '5726', 'iata': 'KQ5726', 'icao': '...     None  None
# 97  {'number': '102', 'iata': 'KQ102', 'icao': 'KQ...     None  None
# 98  {'number': '7551', 'iata': 'DL7551', 'icao': '...     None  None
# 99  {'number': '9237', 'iata': 'HZ9237', 'icao': '...     None  None
#
# [100 rows x 8 columns]

# %%
pd.isna(df).sum()
# Out:
# flight_date        0
# flight_status      0
# departure          0
# arrival            0
# airline            0
# flight             0
# aircraft         100
# live             100
# dtype: int64

# %%
feature3 = [df.get('number') for i in df[["flight"]]]
feature3
# Out:
# [None]

# %%
df[["flight"]]
# Out:
#                                                flight
# 0   {'number': '832', 'iata': 'XY832', 'icao': 'KN...
# 1   {'number': '4511', 'iata': 'ET4511', 'icao': '...
# 2   {'number': '824', 'iata': 'RJ824', 'icao': 'RJ...
# 3   {'number': '650', 'iata': 'RJ650', 'icao': 'RJ...
# 4   {'number': '6101', 'iata': 'QR6101', 'icao': '...
# ..                                                ...
# 95  {'number': '430', 'iata': 'SV430', 'icao': 'SV...
# 96  {'number': '5726', 'iata': 'KQ5726', 'icao': '...
# 97  {'number': '102', 'iata': 'KQ102', 'icao': 'KQ...
# 98  {'number': '7551', 'iata': 'DL7551', 'icao': '...
# 99  {'number': '9237', 'iata': 'HZ9237', 'icao': '...
#
# [100 rows x 1 columns]

# %%
df[["flight_date"]]
# Out:
#    flight_date
# 0   2023-04-29
# 1   2023-04-29
# 2   2023-04-29
# 3   2023-04-29
# 4   2023-04-29
# ..         ...
# 95  2023-04-29
# 96  2023-04-29
# 97  2023-04-29
# 98  2023-04-29
# 99  2023-04-29
#
# [100 rows x 1 columns]

# %%
df[["year"]] = df[["flight_date"]].split("-")[0]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 df[["year"]] = df[["flight_date"]].split("-")[0]
#
# File ~\miniconda3\envs\ironhack\lib\site-packages\pandas\core\generic.py:5989, in NDFrame.__getattr__(self, name)
#    5982 if (
#    5983     name not in self._internal_names_set
#    5984     and name not in self._metadata
#    5985     and name not in self._accessors
#    5986     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987 ):
#    5988     return self[name]
# -> 5989 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'split'
