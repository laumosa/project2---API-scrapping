# %%
import src.extraction as extract
import src.cleaning as clean
import src.visualization as viz
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
df_csv_temp = extract.open_csv_df_temperature('city_temperature')
df_csv_covid = extract.open_csv_df_covid('casos_tecnica_provincia')
df_1 = extract.open_api_df_1('https://api.openaq.org/v1/measurements')
df_2 = extract.open_api_df_2('https://api.openaq.org/v1/measurements')

# %%
# Concatenate both API dataframes:
df_api = pd.concat([df_1, df_2], axis=0, ignore_index=True)

# %%
df_csv_temp = clean.basic_cleaning_csv_temperature(df_csv_temp)
df_csv_covid = clean.basic_cleaning_csv_covid(df_csv_covid)
df_api = clean.basic_cleaning_api(df_api)

# %%
viz.visualizing_csv_temperature(df_csv_temp)

# %%
viz.visualizing_csv_covid(df_csv_covid)

# %%
viz.visualizing_api_barplot(df_api)

# %%
viz.visualizing_api_boxplot(df_api)
